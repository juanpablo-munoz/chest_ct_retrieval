# %% [markdown]
# # Setup inicial

# %%
# Paths & URLs

import os

# Directorio base
#PATH_BASE = '/content/drive/MyDrive/proximity'
#PATH_BASE = 'C:\\Users\\User\\Documents\\Proyecto Proximity'
#PATH_BASE = 'E:\\files\\Documents\\Proyecto Proximity'
PATH_BASE = '/dataChivo/batch_01/bigdata_02/datareleases/'
USER_HOME_PATH = '/dataChivo/jpmunoz/'

# Data release 70
DATA_RELEASE_PATH = os.path.join(PATH_BASE, 'datalake_sorted')
DR70_PATH = os.path.join(PATH_BASE, 'DR70')
DR70_LABELS_PATH = os.path.join(DR70_PATH, 'labels.csv')

# Data release 217
DR217_PATH = os.path.join(PATH_BASE, 'DR217')
DR217_CT_PATH = os.path.join(DR217_PATH, 'DR217_studies')
# Used for normalization of the intensity values for each CT
DR217_CT_HISTOGRAM_LANDMARKS_PATH = os.path.join(DR217_PATH, 'DR217_histogram_landmarks.npy')
DR217_LABELS_PATH = os.path.join(DR217_PATH, 'DR217_labels.csv')
# Embeddings ResNet18 DR217
DR217_RESNET_EMBEDDINGS_PATH = os.path.join(DR217_PATH, 'DR217_resnet18_embeddings_v2')
DR217_PREPROCESSED_PATH = os.path.join(DR217_PATH, 'DR217_preprocessed')
DR217_PREPROCESSED_DOWNSIZED_PATH = os.path.join(DR217_PATH, 'DR217_preprocessed_downsized')


# Data release 2156
DR2156_DATARELEASE_PATH = os.path.join(PATH_BASE, 'DR2156')
DR2156_DATARELEASE_CT_PATH = os.path.join(DR2156_DATARELEASE_PATH, 'DR2156_studies')
DR2156_DATARELEASE_LABELS_PATH = os.path.join(DR2156_DATARELEASE_PATH, 'DR2156_labels', 'DR2156_labels.csv')

# Embeddings ResNet18 DR2156 con dimensiones 300x300x300
DR2156_300_RESNET_EMBEDDINGS_PATH = os.path.join(USER_HOME_PATH, 'chest_ct_retrieval', 'data', 'DR2156', 'DR2156_300_resnet18_embeddings')
DR2156_300_PREPROCESSED_PATH = os.path.join(USER_HOME_PATH, 'chest_ct_retrieval', 'data', 'DR2156', 'DR2156_300_preprocessed')
DR2156_300_PREPROCESSED_ZARR_PATH = os.path.join(USER_HOME_PATH, 'chest_ct_retrieval', 'data', 'DR2156', 'DR2156_300_preprocessed_zarr')

# Embeddings ResNet18 DR2156 con dimensiones 512x512x300
DR2156_512_RESNET_EMBEDDINGS_PATH = os.path.join(USER_HOME_PATH, 'experimentos', 'datasets', 'DR2156', 'DR2156_512_resnet18_embeddings')
DR2156_512_PREPROCESSED_PATH = os.path.join(USER_HOME_PATH, 'experimentos', 'datasets', 'DR2156', 'DR2156_512_preprocessed')


# CTs in Nibabel format
CT_NIBABEL_PATH = os.path.join(PATH_BASE, 'DR70', 'CTs')
CT_NIBABEL_ZERO_PADDED_PATH = os.path.join(PATH_BASE, 'DR70', 'CTs', 'zero_padded')

# Embeddings visuales de CTs
CT_EMBEDDINGS_PATH = DATA_RELEASE_PATH + '/visual_embeddings'


# Etiquetas de los CTs del data release actual
#CT_LABELS_CSV_PATH = DATA_RELEASE_PATH + '/labels.csv'

# Data release (CTs + etiquetas) organizados en un DataFrame
CT_DATASET_DF_HDF_PATH = os.path.join(PATH_BASE, 'dataset_df.h5')
CT_DATASET_DF_PICKLE_PATH = os.path.join(PATH_BASE, 'dataset_df.pickle')

# URLs de modelos visuales
RESNET18_URL = 'microsoft/resnet-18'

# Path que contiene los resnet50 embeddings de CTs del data release actual
CT_RESNET18_EMBEDDINGS_PATH = os.path.join(DR70_PATH, 'visual_embeddings', 'resnet18')
CT_RESNET18_EMBEDDINGS_PATH_ZERO_PADDED = os.path.join(DR70_PATH, 'visual_embeddings', 'resnet18', 'zero_padded')
CT_RESNET18_EMBEDDINGS_PATH_NN_INTERPOLATED = os.path.join(DR70_PATH, 'visual_embeddings', 'resnet18', 'nn_interpolated')

# %%
import os
import pandas as pd
import numpy as np
import torch
import torchio as tio
from torch.utils.data import Dataset, random_split, RandomSampler, BatchSampler
from scipy.spatial.distance import hamming
import random
import logging

# Set seeds
random.seed(0)
np.random.seed(0)
torch.manual_seed(0)
#torch.cuda.manual_seed(0)
#torch.cuda.manual_seed_all(0)

logging.basicConfig(level=logging.INFO)

class ProximityCTDataset(tio.SubjectsDataset):
    def __init__(self, ct_base_path, ct_image_ids, ct_labels_path, histogram_landmarks=None):
        
        self.ct_dir_list = [os.path.join(ct_base_path, ct) for ct in ct_image_ids]

        self.labels_df = pd.read_csv(
            ct_labels_path, 
            header=0, 
            index_col=0, 
            dtype={'CT': str, 'condensacion': int, 'nodulos': int, 'quistes': int}
        )
        
        # Mark those samples that have non-binary label values as not valid
        #self.labels_df['labels_are_valid'] = self.labels_df.apply(self._determine_valid_labels, axis=1)
        self.labels_df['labels_are_valid'] = True
        self.labels_df = self.labels_df.replace(to_replace=9, value=0)

        s_list = []
        #for s_id in ct_image_ids:
        for (s_dir, s_id) in zip(self.ct_dir_list, ct_image_ids):
            #print('Procesando: ' + s_id)
            label_attribs = self._get_ct_label_data(s_id)
            s = tio.Subject(
                t1 = tio.ScalarImage(os.path.join(ct_base_path, s_id)),
                #image_path = os.path.join(ct_base_path, s_id),
                image_path = s_dir,
                name = s_id,
                **label_attribs
            )
            s_list.append(s)

        # Transforms and augmentations to apply to images in the dataset
        s_transforms = tio.Compose([
            tio.ToCanonical(),
            tio.Resample(1),
            tio.CropOrPad(target_shape=(300, 300, 300), padding_mode='constant'),
            tio.Clamp(out_min=-1000, out_max=200), #Clip Hounsfield units
            tio.RescaleIntensity(out_min_max=(-1, 1)),
        ])

        # Filter out those samples with invalid labels
        s_list = [s for s in s_list if s['labels_are_valid']]
        
        super().__init__(s_list, transform=s_transforms, load_getitem=False)
        
    def _determine_valid_labels(self, row):
        if (row['condensacion'] == 1 or row['condensacion'] == 0) \
        and (row['nodulos'] == 1 or row['nodulos'] == 0) \
        and (row['quistes'] == 1 or row['quistes'] == 0):
            return True
        return False

    def _get_ct_label_data(self, ct_code):
        #result = self.labels_df.loc[self.labels_df['CT'] == ct_code+'AN'].to_dict('records')
        result = self.labels_df.loc[self.labels_df['CT'] == ct_code].to_dict('records')
        if result:
            r = result[0]
            r['labels_as_vector'] = self._get_label_vector(r)
            return r
        else:
            return {'labels_are_valid': False}

    def _get_label_vector(self, labels_dict):
        c = int(labels_dict['condensacion'])
        n = int(labels_dict['nodulos'])
        q = int(labels_dict['quistes'])
        no_anomalies = int(not 1 in [c, n, q])
        return [no_anomalies, c, n, q]

# %%
import random

subject_list = [dirname for dirname in os.listdir(DR2156_DATARELEASE_CT_PATH)]

subject_subset = random.sample(subject_list, 5)

dataset = ProximityCTDataset(DR2156_DATARELEASE_CT_PATH, subject_list, DR2156_DATARELEASE_LABELS_PATH)

# %%
dataset.labels_df.head()
# Out:
#          CT  condensacion  nodulos  quistes  labels_are_valid
# 0  01003316             0        0        0              True
# 1  01003335             0        0        0              True
# 2  01003352             0        1        0              True
# 3  01003431             0        1        0              True
# 4  01003686             0        1        0              True

# %%
s = dataset[2]

print(s['t1']['data'][0].shape)
print(torch.min(s['t1']['data'][0]))
print(torch.max(s['t1']['data'][0]))
#print(s['t1']['data'][0])
s.plot(figsize=(10, 30))
# Out:
# WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x1181ebf0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49312
# torch.Size([300, 300, 300])
# tensor(-1.)
# tensor(1.)

# %% [markdown]
# # Experimentación con normalización por histograma (ignorar, ya que terminé por no aplicarlo)

# %%
from scipy import stats
import matplotlib.pyplot as plt
from tqdm.auto import tqdm

def plot_histogram(axis, tensor, num_positions=100, label=None, alpha=0.1, color=None):
    values = tensor.numpy().ravel()
    kernel = stats.gaussian_kde(values)
    positions = np.linspace(values.min(), values.max(), num=num_positions)
    histogram = kernel(positions)
    kwargs = dict(linewidth=1, color='black' if color is None else color, alpha=alpha)
    if label is not None:
        kwargs['label'] = label
    axis.plot(positions, histogram, **kwargs)


fig, ax = plt.subplots(dpi=100)
for s in tqdm(dataset):
    tensor = s['t1']['data']
    #if 'HH' in path.name: color = 'red'
    #elif 'Guys' in path.name: color = 'green'
    #elif 'IOP' in path.name: color = 'blue'
    plot_histogram(ax, tensor)
ax.set_xlim(-1500, 3500)
ax.set_ylim(0, 0.004)
ax.set_title('Original histograms of all samples')
ax.set_xlabel('Intensity')
ax.grid()
graph = None
# Out:
#   0%|          | 0/217 [00:00<?, ?it/s]

# %%
subject_list = [dirname for dirname in os.listdir(DR217_CT_PATH)]
subject_path_list = [os.path.join(DR217_CT_PATH, s_id) for s_id in subject_list]

landmarks = tio.HistogramStandardization.train(
    subject_path_list,
    output_path=DR217_CT_HISTOGRAM_LANDMARKS_PATH,
)
np.set_printoptions(suppress=True, precision=3)
print('\nTrained landmarks:', landmarks)
# Out:
#   0%|          | 0/217 [00:00<?, ?it/s]
# Trained landmarks: [  0.      2.062   4.523   6.237   8.569  18.213  36.948  53.601  60.422
#   62.771  65.159  71.262 100.   ]

# %%
import matplotlib.pyplot as plt
from tqdm.auto import tqdm
from scipy import stats

landmarks_dict = {'t1': landmarks}
histogram_transform = tio.HistogramStandardization(landmarks_dict)

subject_list = [dirname for dirname in os.listdir(DR217_CT_PATH)]
subject_subset = random.sample(subject_list, 5)
dataset = ProximityCTDataset(DR217_CT_PATH, subject_subset, DR217_LABELS_PATH)


def plot_histogram(axis, tensor, num_positions=100, label=None, alpha=0.1, color=None):
    values = tensor.numpy().ravel()
    kernel = stats.gaussian_kde(values)
    positions = np.linspace(values.min(), values.max(), num=num_positions)
    histogram = kernel(positions)
    kwargs = dict(linewidth=1, color='black' if color is None else color, alpha=alpha)
    if label is not None:
        kwargs['label'] = label
    axis.plot(positions, histogram, **kwargs)


fig, ax = plt.subplots(dpi=100)
for i ,sample in enumerate(tqdm(dataset)):
    standard = histogram_transform(sample)
    tensor = standard.t1.data
    #path = str(sample.mri.path)
    #if 'HH' in path: color = 'red'
    #elif 'Guys' in path: color = 'green'
    #elif 'IOP' in path: color = 'blue'
    plot_histogram(ax, tensor)
ax.set_xlim(0, 150)
ax.set_ylim(0, 0.02)
ax.set_title('Intensity values of all samples after histogram standardization')
ax.set_xlabel('Intensity')
ax.grid()
graph = None
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]

# %%
d = dataset[3]
rescaled_d = tio.RescaleIntensity(out_min_max=(0, 255))(d)
histogramed_d = histogram_transform(d)
print(d['labels_as_vector'])
print(d['t1']['data'])
print(rescaled_d['t1']['data'].int())
rescaled_d.plot(figsize=(10, 30))
histogramed_d.plot(figsize=(10, 30))
# Out:
# [0, 1, 0]
# tensor([[[[-1016,  -939,  -941,  ...,  -976, -1003,  -997],
#           [ -866,  -787,  -907,  ...,  -913,  -972, -1002],
#           [ -874,  -949, -1012,  ...,  -944, -1002, -1011],
#           ...,
#           [ -979,  -981,  -987,  ...,  -962, -1005,  -960],
#           [ -740,  -735,  -883,  ...,  -896,  -987,  -989],
#           [ -922,  -951,  -940,  ...,  -760,  -813,  -835]],
#
#          [[-1016, -1000,  -983,  ..., -1003,  -968,  -934],
#           [-1018,  -936,  -826,  ...,  -989,  -950,  -935],
#           [ -714,  -848,  -853,  ...,  -934,  -883,  -879],
#           ...,
#           [ -834,  -883,  -939,  ...,  -956,  -993, -1006],
#           [ -818,  -835,  -881,  ...,  -876,  -798,  -845],
#           [ -974,  -994,  -901,  ...,  -862,  -790,  -752]],
#
#          [[ -825,  -915, -1000,  ...,  -935,  -906,  -978],
#           [-1008,  -996, -1019,  ..., -1010, -1007, -1006],
#           [-1016,  -968,  -911,  ...,  -985,  -950,  -953],
#           ...,
#           [ -950,  -902,  -961,  ...,  -884,  -868,  -889],
#           [ -985,  -973,  -895,  ...,  -843,  -744,  -811],
#           [ -926,  -939,  -842,  ...,  -895,  -798,  -779]],
#
#          ...,
#
#          [[ -980,  -911,  -939,  ...,  -963,  -996,  -984],
#           [ -992,  -999, -1009,  ...,  -925,  -978,  -946],
#           [ -955,  -959,  -945,  ...,  -971,  -964,  -965],
#           ...,
#           [ -324,  -195,   -28,  ...,   288,   451,   287],
#           [ -832,  -761,  -694,  ...,  -245,  -153,    29],
#           [ -884,  -947,  -921,  ...,  -746,  -698,  -587]],
#
#          [[-1003,  -983,  -997,  ...,  -944, -1006,  -990],
#           [ -955, -1008, -1005,  ...,  -937,  -965, -1014],
#           [ -942,  -964,  -919,  ..., -1001,  -989,  -971],
#           ...,
#           [ -630,  -516,  -509,  ...,   251,   249,   242],
#           [-1008,  -955,  -928,  ...,  -502,  -428,  -289],
#           [ -905,  -887,  -930,  ...,  -894,  -930,  -906]],
#
#          [[-1014, -1022, -1021,  ...,  -978,  -987,  -971],
#           [-1013, -1021, -1003,  ..., -1004,  -974,  -978],
#           [ -965,  -915,  -951,  ..., -1012,  -992,  -953],
#           ...,
#           [ -740,  -802,  -797,  ...,   108,   222,   115],
#           [ -934,  -984,  -952,  ...,  -775,  -659,  -728],
#           [ -904,  -916,  -953,  ...,  -869,  -883,  -992]]]],
#        dtype=torch.int16)
# tensor([[[[ 0,  5,  5,  ...,  2,  1,  1],
#           [ 9, 14,  7,  ...,  6,  3,  1],
#           [ 9,  4,  0,  ...,  4,  1,  0],
#           ...,
#           [ 2,  2,  2,  ...,  3,  1,  3],
#           [17, 17,  8,  ...,  7,  2,  2],
#           [ 6,  4,  5,  ..., 16, 13, 11]],
#
#          [[ 0,  1,  2,  ...,  1,  3,  5],
#           [ 0,  5, 12,  ...,  2,  4,  5],
#           [19, 10, 10,  ...,  5,  8,  9],
#           ...,
#           [11,  8,  5,  ...,  4,  1,  1],
#           [12, 11,  8,  ...,  9, 14, 11],
#           [ 3,  1,  7,  ..., 10, 14, 16]],
#
#          [[12,  6,  1,  ...,  5,  7,  2],
#           [ 0,  1,  0,  ...,  0,  1,  1],
#           [ 0,  3,  7,  ...,  2,  4,  4],
#           ...,
#           [ 4,  7,  3,  ...,  8,  9,  8],
#           [ 2,  3,  8,  ..., 11, 17, 13],
#           [ 6,  5, 11,  ...,  8, 14, 15]],
#
#          ...,
#
#          [[ 2,  7,  5,  ...,  3,  1,  2],
#           [ 1,  1,  0,  ...,  6,  2,  4],
#           [ 4,  4,  4,  ...,  3,  3,  3],
#           ...,
#           [43, 51, 62,  ..., 81, 91, 81],
#           [11, 16, 20,  ..., 48, 54, 65],
#           [ 8,  4,  6,  ..., 17, 20, 27]],
#
#          [[ 1,  2,  1,  ...,  4,  1,  2],
#           [ 4,  0,  1,  ...,  5,  3,  0],
#           [ 5,  3,  6,  ...,  1,  2,  3],
#           ...,
#           [24, 31, 32,  ..., 79, 79, 78],
#           [ 0,  4,  5,  ..., 32, 37, 45],
#           [ 7,  8,  5,  ...,  8,  5,  7]],
#
#          [[ 0,  0,  0,  ...,  2,  2,  3],
#           [ 0,  0,  1,  ...,  1,  3,  2],
#           [ 3,  6,  4,  ...,  0,  1,  4],
#           ...,
#           [17, 13, 14,  ..., 70, 77, 70],
#           [ 5,  2,  4,  ..., 15, 22, 18],
#           [ 7,  6,  4,  ...,  9,  8,  1]]]], dtype=torch.int32)

# %% [markdown]
# # Instanciar modelo ResNet y generar embeddings a partir de los CTs

# %%
from torch import nn
from torchvision import models

class CTEmbeddingModel(nn.Module):
    def __init__(self):
        super(CTEmbeddingModel, self).__init__()
        
        resnet = models.resnet18(weights='DEFAULT')
        self.features = nn.Sequential(*(list(resnet.children())[:-2]))

        '''
        #conv input torch.Size([1,83,512,14,14])
        self.reducingconvs = nn.Sequential(
            nn.Conv3d(28, 16, kernel_size = (3,3,3), stride=(3,1,1), padding=0),
            nn.ReLU(),
            
            #nn.Conv3d(16, 8, kernel_size = (3,3,3), stride=(3,1,1), padding=0),
            #nn.ReLU(),
            
            #nn.Conv3d(8, 4, kernel_size = (3,1,1), stride=(3,1,1), padding=0),
            #nn.ReLU()
        )
        
        self.fc = nn.Sequential(
            nn.Linear(16*170*3*3, 512),
            nn.ReLU(True),
            nn.Dropout(0.5),
            
            nn.Linear(512, 256), 
            nn.ReLU(True),
            nn.Dropout(0.5),
            
            nn.Linear(256, 2))
        '''
      
    def forward(self, x):
        #print('input shape', x.shape)
        #x = x.permute(0, 3, 1, 2)
        #print(x.shape)
        shape = list(x.size())
        #example shape: [1,83,3,290,290]
        #example shape: [2,83,3,290,290]
        batch_size = int(shape[0])
        x = x.view(batch_size*100,3,300,300)
        x = self.features(x)
        #print('resnet output shape:', x.size())
        '''
        x = x.view(batch_size,28,512,5,5)
        x = self.reducingconvs(x)
        #output is shape [batch_size, 16, 18, 3, 3]
        #print('reducingconvs output shape:', x.size())
        x = x.view(batch_size, 16*170*3*3)
        x = self.fc(x)
        '''
        return x

# %%
from torchvision.transforms import v2
from tqdm import tqdm

model = CTEmbeddingModel()
model.eval()
model.cuda()

# input tensor comes in the range [0, 1]
# only remaining steps to complete Z-Normalization for ResNet is substrating the mean of 0.449 and dividing each pixel by the std of 0.226.
transforms_composite = v2.Compose([
    #v2.Grayscale(num_output_channels=1),
    #v2.Resize((100, 100)),
    v2.ToDtype(torch.float32, scale=True), # with scale=True, scales pixel values from [0, 255] to [0.0, 1.0]
    v2.Normalize(mean=[0.449], std=[0.226])
])
counter = 0
with torch.no_grad():
    for s in tqdm(dataset):
        counter += 1
        
        input_normalized = transforms_composite(torch.tensor(s['t1']['data']).detach().clone())
        number_formatted = '{:03d}'.format(counter)
        labels_formatted = '_'.join([str(l) for l in s['labels_as_vector']])
        name = number_formatted + '_' + s['name'] + '_' + labels_formatted
        embedding = model(input_normalized.cuda()).cpu().numpy()
        label = np.array(s['labels_as_vector'])
        np.savez_compressed(os.path.join(DR2156_300_RESNET_EMBEDDINGS_PATH, name), name=name, embedding=embedding, label=label)
        np.savez_compressed(os.path.join(DR2156_300_PREPROCESSED_PATH, name), name=name, volume=input_normalized.cpu().numpy().astype(np.float16), label=label)
# Out:
#   0%|                                                                                                                                                                                               | 0/2156 [00:00<?, ?it/s]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49327
#
# /tmp/ipykernel_204648/3635823187.py:21: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   input_normalized = transforms_composite(torch.tensor(s['t1']['data']).clone().detach())
#   0%|                                                                                                                                                                                     | 1/2156 [00:08<4:47:22,  8.00s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49246
#
#   0%|▏                                                                                                                                                                                    | 2/2156 [00:17<5:25:57,  9.08s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49312
#
#   0%|▎                                                                                                                                                                                    | 3/2156 [00:29<6:04:13, 10.15s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49231
#
#   0%|▎                                                                                                                                                                                    | 4/2156 [00:39<6:11:41, 10.36s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49242
#
#   0%|▍                                                                                                                                                                                    | 5/2156 [00:50<6:11:59, 10.38s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.48492
#
#   0%|▌                                                                                                                                                                                    | 6/2156 [01:00<6:15:08, 10.47s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49336
#
#   0%|▌                                                                                                                                                                                    | 7/2156 [01:12<6:24:47, 10.74s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49451
#
#   0%|▋                                                                                                                                                                                    | 8/2156 [01:36<9:03:31, 15.18s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49261
#
#   0%|▊                                                                                                                                                                                    | 9/2156 [01:46<8:01:19, 13.45s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49476
#
#   0%|▊                                                                                                                                                                                   | 10/2156 [02:10<9:56:06, 16.67s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49375
#
#   1%|▉                                                                                                                                                                                   | 11/2156 [02:21<8:50:06, 14.83s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49398
#
#   1%|█                                                                                                                                                                                   | 12/2156 [02:32<8:10:38, 13.73s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49324
#
#   1%|█                                                                                                                                                                                   | 13/2156 [02:43<7:46:55, 13.07s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49171
#
#   1%|█▏                                                                                                                                                                                  | 14/2156 [02:53<7:10:58, 12.07s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49275
#
#   1%|█▎                                                                                                                                                                                  | 15/2156 [03:04<6:57:37, 11.70s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49359
#
#   1%|█▎                                                                                                                                                                                  | 16/2156 [03:15<6:48:26, 11.45s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49312
#
#   1%|█▍                                                                                                                                                                                  | 17/2156 [03:26<6:43:28, 11.32s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49302
#
#   1%|█▌                                                                                                                                                                                  | 18/2156 [03:37<6:40:13, 11.23s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49206
#
#   1%|█▌                                                                                                                                                                                  | 19/2156 [03:47<6:25:45, 10.83s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.4925
#
#   1%|█▋                                                                                                                                                                                  | 20/2156 [03:57<6:16:00, 10.56s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49292
#
#   1%|█▊                                                                                                                                                                                  | 21/2156 [04:07<6:13:27, 10.50s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49367
#
#   1%|█▊                                                                                                                                                                                  | 22/2156 [04:19<6:30:24, 10.98s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49425
#
#   1%|█▉                                                                                                                                                                                  | 23/2156 [04:31<6:43:03, 11.34s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49345
#
#   1%|██                                                                                                                                                                                  | 24/2156 [04:43<6:40:24, 11.27s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49206
#
#   1%|██                                                                                                                                                                                  | 25/2156 [04:54<6:41:34, 11.31s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49202
#
#   1%|██▏                                                                                                                                                                                 | 26/2156 [05:04<6:28:22, 10.94s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49364
#
#   1%|██▎                                                                                                                                                                                 | 27/2156 [05:16<6:39:02, 11.25s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49211
#
#   1%|██▎                                                                                                                                                                                 | 28/2156 [05:26<6:26:00, 10.88s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49299
#
#   1%|██▍                                                                                                                                                                                 | 29/2156 [05:37<6:23:10, 10.81s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49102
#
#   1%|██▌                                                                                                                                                                                 | 30/2156 [05:45<6:00:24, 10.17s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49318
#
#   1%|██▌                                                                                                                                                                                 | 31/2156 [05:55<5:59:40, 10.16s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49419
#
#   1%|██▋                                                                                                                                                                                 | 32/2156 [06:07<6:15:27, 10.61s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49102
#
#   2%|██▊                                                                                                                                                                                 | 33/2156 [06:16<5:57:16, 10.10s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49339
#
#   2%|██▊                                                                                                                                                                                 | 34/2156 [06:27<6:02:56, 10.26s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49231
#
#   2%|██▉                                                                                                                                                                                 | 35/2156 [06:37<6:02:28, 10.25s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49176
#
#   2%|███                                                                                                                                                                                 | 36/2156 [06:46<5:55:20, 10.06s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49359
#
#   2%|███                                                                                                                                                                                 | 37/2156 [07:02<6:51:32, 11.65s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49427
#
#   2%|███▏                                                                                                                                                                                | 38/2156 [07:13<6:47:59, 11.56s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49423
#
#   2%|███▎                                                                                                                                                                                | 39/2156 [07:24<6:41:22, 11.38s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49321
#
#   2%|███▍                                                                                                                                                                                | 41/2156 [07:45<6:18:26, 10.74s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49038
#
#   2%|███▌                                                                                                                                                                                | 42/2156 [07:56<6:22:51, 10.87s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49327
#
#   2%|███▌                                                                                                                                                                                | 43/2156 [08:07<6:26:36, 10.98s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.48636
#
#   2%|███▋                                                                                                                                                                                | 44/2156 [08:13<5:35:38,  9.54s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49296
#
#   2%|███▊                                                                                                                                                                                | 45/2156 [08:23<5:40:21,  9.67s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49282
#
#   2%|███▊                                                                                                                                                                                | 46/2156 [08:34<5:54:04, 10.07s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49239
#
#   2%|███▉                                                                                                                                                                                | 47/2156 [08:44<5:54:18, 10.08s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49246
#
#   2%|████                                                                                                                                                                                | 48/2156 [08:55<5:57:12, 10.17s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49268
#
#   2%|████                                                                                                                                                                                | 49/2156 [09:05<5:57:54, 10.19s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49246
#
#   2%|████▏                                                                                                                                                                               | 50/2156 [09:15<6:01:08, 10.29s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49272
#
#   2%|████▎                                                                                                                                                                               | 51/2156 [09:26<6:01:54, 10.32s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49063
#
#   2%|████▎                                                                                                                                                                               | 52/2156 [09:36<6:03:00, 10.35s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49312
#
#   2%|████▍                                                                                                                                                                               | 53/2156 [09:47<6:06:23, 10.45s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49239
#
#   3%|████▌                                                                                                                                                                               | 54/2156 [09:57<6:04:47, 10.41s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.4925
#
#   3%|████▌                                                                                                                                                                               | 55/2156 [10:11<6:44:25, 11.55s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49296
#
#   3%|████▋                                                                                                                                                                               | 56/2156 [10:22<6:38:09, 11.38s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:2.4875
#
#   3%|████▊                                                                                                                                                                               | 57/2156 [10:46<8:50:04, 15.15s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49286
#
#   3%|████▊                                                                                                                                                                               | 58/2156 [10:57<8:01:55, 13.78s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49359
#
#   3%|████▉                                                                                                                                                                               | 59/2156 [11:07<7:26:28, 12.77s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49318
#
#   3%|█████                                                                                                                                                                               | 60/2156 [11:18<7:02:45, 12.10s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49275
#
#   3%|█████                                                                                                                                                                               | 61/2156 [11:28<6:42:05, 11.52s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49427
#
#   3%|█████▏                                                                                                                                                                              | 62/2156 [11:40<6:42:51, 11.54s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49257
#
#   3%|█████▎                                                                                                                                                                              | 63/2156 [11:50<6:30:17, 11.19s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49345
#
#   3%|█████▎                                                                                                                                                                              | 64/2156 [12:01<6:29:12, 11.16s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49219
#
#   3%|█████▍                                                                                                                                                                              | 65/2156 [12:11<6:12:26, 10.69s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.48986
#
#   3%|█████▌                                                                                                                                                                              | 66/2156 [12:18<5:36:09,  9.65s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49153
#
#   3%|█████▌                                                                                                                                                                              | 67/2156 [12:27<5:31:00,  9.51s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49362
#
#   3%|█████▋                                                                                                                                                                              | 68/2156 [12:38<5:48:41, 10.02s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49289
#
#   3%|█████▊                                                                                                                                                                              | 69/2156 [12:49<5:56:10, 10.24s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49143
#
#   3%|█████▊                                                                                                                                                                              | 70/2156 [12:58<5:42:34,  9.85s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49272
#
#   3%|█████▉                                                                                                                                                                              | 71/2156 [13:09<5:53:32, 10.17s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49202
#
#   3%|██████                                                                                                                                                                              | 72/2156 [13:19<5:51:29, 10.12s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49375
#
#   3%|██████                                                                                                                                                                              | 73/2156 [13:30<6:01:43, 10.42s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49367
#
#   3%|██████▏                                                                                                                                                                             | 74/2156 [13:41<6:06:44, 10.57s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49026
#
#   3%|██████▎                                                                                                                                                                             | 75/2156 [13:49<5:40:34,  9.82s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49409
#
#   4%|██████▎                                                                                                                                                                             | 76/2156 [14:01<5:58:06, 10.33s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49257
#
#   4%|██████▍                                                                                                                                                                             | 77/2156 [14:10<5:50:56, 10.13s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49286
#
#   4%|██████▌                                                                                                                                                                             | 78/2156 [14:21<5:54:06, 10.22s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.494
#
#   4%|██████▌                                                                                                                                                                             | 79/2156 [14:32<6:03:08, 10.49s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49345
#
#   4%|██████▋                                                                                                                                                                             | 80/2156 [14:42<5:58:34, 10.36s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49194
#
#   4%|██████▊                                                                                                                                                                             | 81/2156 [14:51<5:47:15, 10.04s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49292
#
#   4%|██████▊                                                                                                                                                                             | 82/2156 [15:02<5:53:43, 10.23s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49296
#
#   4%|██████▉                                                                                                                                                                             | 83/2156 [15:12<5:52:23, 10.20s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49112
#
#   4%|███████                                                                                                                                                                             | 84/2156 [15:20<5:31:38,  9.60s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49362
#
#   4%|███████                                                                                                                                                                             | 85/2156 [15:31<5:41:28,  9.89s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49312
#
#   4%|███████▏                                                                                                                                                                            | 86/2156 [15:41<5:46:02, 10.03s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49405
#
#   4%|███████▎                                                                                                                                                                            | 87/2156 [15:52<5:58:56, 10.41s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.48462
#
#   4%|███████▎                                                                                                                                                                            | 88/2156 [16:02<5:51:46, 10.21s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49272
#
#   4%|███████▍                                                                                                                                                                            | 89/2156 [16:13<5:54:44, 10.30s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49268
#
#   4%|███████▌                                                                                                                                                                            | 90/2156 [16:23<5:51:52, 10.22s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49206
#
#   4%|███████▌                                                                                                                                                                            | 91/2156 [16:32<5:46:53, 10.08s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49306
#
#   4%|███████▋                                                                                                                                                                            | 92/2156 [16:43<5:50:55, 10.20s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49239
#
#   4%|███████▊                                                                                                                                                                            | 93/2156 [16:53<5:49:04, 10.15s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49176
#
#   4%|███████▊                                                                                                                                                                            | 94/2156 [17:03<5:50:56, 10.21s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49378
#
#   4%|███████▉                                                                                                                                                                            | 95/2156 [17:14<6:00:23, 10.49s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49348
#
#   4%|████████                                                                                                                                                                            | 96/2156 [17:26<6:06:54, 10.69s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49296
#
#   4%|████████                                                                                                                                                                            | 97/2156 [17:36<6:03:14, 10.59s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49302
#
#   5%|████████▏                                                                                                                                                                           | 98/2156 [17:46<6:03:10, 10.59s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49286
#
#   5%|████████▎                                                                                                                                                                           | 99/2156 [17:57<6:02:20, 10.57s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.48558
#
#   5%|████████▎                                                                                                                                                                          | 100/2156 [18:07<5:59:23, 10.49s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49351
#
#   5%|████████▍                                                                                                                                                                          | 101/2156 [18:19<6:06:37, 10.70s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49353
#
#   5%|████████▍                                                                                                                                                                          | 102/2156 [18:30<6:10:11, 10.81s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49299
#
#   5%|████████▌                                                                                                                                                                          | 103/2156 [18:41<6:11:18, 10.85s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49246
#
#   5%|████████▋                                                                                                                                                                          | 104/2156 [18:50<5:58:58, 10.50s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49279
#
#   5%|████████▋                                                                                                                                                                          | 105/2156 [19:04<6:37:25, 11.63s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49235
#
#   5%|████████▊                                                                                                                                                                          | 106/2156 [19:14<6:15:33, 10.99s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49185
#
#   5%|████████▉                                                                                                                                                                          | 107/2156 [19:24<6:01:09, 10.58s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49351
#
#   5%|████████▉                                                                                                                                                                          | 108/2156 [19:35<6:04:55, 10.69s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.4918
#
#   5%|█████████                                                                                                                                                                          | 109/2156 [19:44<5:50:21, 10.27s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49235
#
#   5%|█████████▏                                                                                                                                                                         | 110/2156 [19:54<5:45:30, 10.13s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.4933
#
#   5%|█████████▏                                                                                                                                                                         | 111/2156 [20:04<5:47:14, 10.19s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49324
#
# ...
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49275
#
#  51%|█████████████████████████████████████████████████████████████████████████████████████████▋                                                                                      | 1099/2156 [3:28:07<3:39:46, 12.48s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49289
#
#  51%|█████████████████████████████████████████████████████████████████████████████████████████▊                                                                                      | 1100/2156 [3:28:33<4:51:47, 16.58s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49333
#
#  51%|█████████████████████████████████████████████████████████████████████████████████████████▉                                                                                      | 1101/2156 [3:28:50<4:52:10, 16.62s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49235
#
#  51%|█████████████████████████████████████████████████████████████████████████████████████████▉                                                                                      | 1102/2156 [3:29:03<4:31:10, 15.44s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49223
#
#  51%|██████████████████████████████████████████████████████████████████████████████████████████                                                                                      | 1103/2156 [3:29:17<4:25:30, 15.13s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49206
#
#  51%|██████████████████████████████████████████████████████████████████████████████████████████                                                                                      | 1104/2156 [3:29:29<4:07:12, 14.10s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49333
#
#  51%|██████████████████████████████████████████████████████████████████████████████████████████▏                                                                                     | 1105/2156 [3:29:41<3:54:40, 13.40s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49148
#
#  51%|██████████████████████████████████████████████████████████████████████████████████████████▎                                                                                     | 1106/2156 [3:29:52<3:43:45, 12.79s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49235
#
#  51%|██████████████████████████████████████████████████████████████████████████████████████████▎                                                                                     | 1107/2156 [3:30:03<3:36:14, 12.37s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.48986
#
#  51%|██████████████████████████████████████████████████████████████████████████████████████████▍                                                                                     | 1108/2156 [3:30:13<3:18:59, 11.39s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49246
#
#  51%|██████████████████████████████████████████████████████████████████████████████████████████▌                                                                                     | 1109/2156 [3:30:25<3:22:01, 11.58s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49254
#
#  51%|██████████████████████████████████████████████████████████████████████████████████████████▌                                                                                     | 1110/2156 [3:30:36<3:20:51, 11.52s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49242
#
#  52%|██████████████████████████████████████████████████████████████████████████████████████████▋                                                                                     | 1111/2156 [3:30:47<3:19:26, 11.45s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49292
#
#  52%|██████████████████████████████████████████████████████████████████████████████████████████▊                                                                                     | 1112/2156 [3:31:00<3:28:51, 12.00s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.4925
#
#  52%|██████████████████████████████████████████████████████████████████████████████████████████▊                                                                                     | 1113/2156 [3:31:12<3:27:48, 11.95s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49242
#
#  52%|██████████████████████████████████████████████████████████████████████████████████████████▉                                                                                     | 1114/2156 [3:31:23<3:19:24, 11.48s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49246
#
#  52%|███████████████████████████████████████████████████████████████████████████████████████████                                                                                     | 1115/2156 [3:31:35<3:25:15, 11.83s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49286
#
#  52%|███████████████████████████████████████████████████████████████████████████████████████████                                                                                     | 1116/2156 [3:31:47<3:25:28, 11.85s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49202
#
#  52%|███████████████████████████████████████████████████████████████████████████████████████████▏                                                                                    | 1117/2156 [3:32:00<3:27:59, 12.01s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49246
#
#  52%|███████████████████████████████████████████████████████████████████████████████████████████▎                                                                                    | 1118/2156 [3:32:11<3:26:20, 11.93s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49282
#
#  52%|███████████████████████████████████████████████████████████████████████████████████████████▎                                                                                    | 1119/2156 [3:32:24<3:30:27, 12.18s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.4918
#
#  52%|███████████████████████████████████████████████████████████████████████████████████████████▍                                                                                    | 1120/2156 [3:33:15<6:50:53, 23.80s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49395
#
#  52%|██████████████████████████████████████████████████████████████████████████████████████████▉                                                                                    | 1121/2156 [3:34:25<10:49:58, 37.68s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49306
#
#  52%|███████████████████████████████████████████████████████████████████████████████████████████                                                                                    | 1122/2156 [3:35:24<12:38:48, 44.03s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49185
#
#  52%|███████████████████████████████████████████████████████████████████████████████████████████▏                                                                                   | 1123/2156 [3:36:21<13:47:49, 48.08s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.4908
#
#  52%|███████████████████████████████████████████████████████████████████████████████████████████▏                                                                                   | 1124/2156 [3:37:47<16:58:47, 59.23s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.48571
#
#  52%|███████████████████████████████████████████████████████████████████████████████████████████▎                                                                                   | 1125/2156 [3:38:46<16:56:20, 59.15s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49254
#
#  52%|███████████████████████████████████████████████████████████████████████████████████████████▍                                                                                   | 1126/2156 [3:39:47<17:06:23, 59.79s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49254
#
#  52%|███████████████████████████████████████████████████████████████████████████████████████████▍                                                                                   | 1127/2156 [3:40:47<17:04:13, 59.72s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49185
#
#  52%|███████████████████████████████████████████████████████████████████████████████████████████▌                                                                                   | 1128/2156 [3:41:42<16:43:11, 58.55s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49268
#
#  52%|███████████████████████████████████████████████████████████████████████████████████████████▋                                                                                   | 1129/2156 [3:42:40<16:36:22, 58.21s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.4937
#
#  52%|███████████████████████████████████████████████████████████████████████████████████████████▋                                                                                   | 1130/2156 [3:44:26<20:44:02, 72.75s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49416
#
#  52%|███████████████████████████████████████████████████████████████████████████████████████████▊                                                                                   | 1131/2156 [3:45:41<20:50:45, 73.21s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.4938
#
#  53%|███████████████████████████████████████████████████████████████████████████████████████████▉                                                                                   | 1132/2156 [3:46:52<20:38:46, 72.58s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49362
#
#  53%|███████████████████████████████████████████████████████████████████████████████████████████▉                                                                                   | 1133/2156 [3:48:01<20:19:11, 71.51s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49353
#
#  53%|████████████████████████████████████████████████████████████████████████████████████████████                                                                                   | 1134/2156 [3:49:07<19:48:55, 69.80s/it]WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f37cfd0): Non uniform sampling or missing slices detected,  maximum nonuniformity:1.49289
#
#  53%|████████████████████████████████████████████████████████████████████████████████████████████▏                                                                                  | 1135/2156 [3:50:07<18:57:06, 66.82s/it]

# %%
import torchio as tio
import numpy as np
import zarr
from numcodecs import Blosc
from pathlib import Path



def preprocess_and_save_zarr():

    transforms = v2.Compose([
        # ImageNet std and mean
        v2.Normalize(mean=[0.449], std=[0.226])
    ])

    for subject in tqdm(dataset):

        # Z-normalize with ImageNet std and mean
        subject = transforms(subject)

        vol = subject.ct.data.squeeze().numpy().astype(np.float16)  # shape: [D, H, W]

        compressor = Blosc(cname='zstd', clevel=5, shuffle=Blosc.BITSHUFFLE)
        z = zarr.open(DR2156_300_PREPROCESSED_ZARR_PATH, mode='w', shape=vol.shape, dtype='float16',
                    chunks=(64, 128, 128), compressor=compressor)
        z[:] = vol

# %%
del tensor, model, subject  # or any other large variables
import gc
gc.collect()
import torch
torch.cuda.empty_cache()
